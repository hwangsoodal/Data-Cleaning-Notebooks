# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/building-permits-san-francisco/Building_Permits.csv

# %%
sf_permits = pd.read_csv('/kaggle/input/building-permits-san-francisco/Building_Permits.csv')
np.random.seed(0)
# Out:
# /tmp/ipykernel_33/3773363338.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_permits = pd.read_csv('/kaggle/input/building-permits-san-francisco/Building_Permits.csv')

# %%
sf_permits.sample(5)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 40553   201403039652            8            otc alterations permit
# 169731  201510159735            3  additions alterations or repairs
# 19180        M409787            8            otc alterations permit
# 68047   201411191888            8            otc alterations permit
# 64238        M527228            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 40553            03/03/2014  3732  008            400                  NaN
# 169731           10/15/2015  2609  028             79                  NaN
# 19180            07/22/2013  4624  031            178                  NaN
# 68047            11/19/2014  0039  109            294                  NaN
# 64238            10/14/2014  1251  002            707                  NaN
#
#         Street Name Street Suffix  ...  Existing Construction Type  \
# ...

# %%
missing_values_count = sf_permits.isnull().sum()

missing_values_count[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
total_cells = np.product(sf_permits.shape)
total_missing = missing_values_count.sum()

(total_missing/total_cells) * 100
# Out:
# 26.26002315058403

# %%
columns_with_na_dropped = sf_permits.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
print("Columns in original dataset: %d \n" % sf_permits.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 43
#
# Columns with na's dropped: 12

# %%
subset_sf_permits = sf_permits.loc[:, 'Block':'Filed Date'].head()
subset_sf_permits
# Out:
#   Block  Lot  Street Number Street Number Suffix Street Name Street Suffix  \
# 0  0326  023            140                  NaN       Ellis            St
# 1  0306  007            440                  NaN       Geary            St
# 2  0595  203           1647                  NaN     Pacific            Av
# 3  0156  011           1230                  NaN     Pacific            Av
# 4  0342  001            950                  NaN      Market            St
#
#    Unit Unit Suffix                                        Description  \
# 0   NaN         NaN  ground fl facade: to erect illuminated, electr...
# 1   0.0         NaN            remove (e) awning and associated signs.
# 2   NaN         NaN                    installation of separating wall
# 3   0.0         NaN           repair dryrot & stucco at front of bldg.
# 4   NaN         NaN  demolish retail/office/commercial 3-story buil...
#
#   Current Status Current Status Date  Filed Date
# ...

# %%
subset_sf_permits.fillna(0)
# Out:
# /tmp/ipykernel_33/3149074871.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   subset_sf_permits.fillna(0)
#   Block  Lot  Street Number  Street Number Suffix Street Name Street Suffix  \
# 0  0326  023            140                     0       Ellis            St
# 1  0306  007            440                     0       Geary            St
# 2  0595  203           1647                     0     Pacific            Av
# 3  0156  011           1230                     0     Pacific            Av
# 4  0342  001            950                     0      Market            St
#
#    Unit  Unit Suffix                                        Description  \
# 0   0.0            0  ground fl facade: to erect illuminated, electr...
# ...

# %%
subset_sf_permits.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
# /tmp/ipykernel_33/137485678.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_sf_permits.fillna(method = 'bfill', axis=0).fillna(0)
# /tmp/ipykernel_33/137485678.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   subset_sf_permits.fillna(method = 'bfill', axis=0).fillna(0)
#   Block  Lot  Street Number  Street Number Suffix Street Name Street Suffix  \
# 0  0326  023            140                   0.0       Ellis            St
# 1  0306  007            440                   0.0       Geary            St
# 2  0595  203           1647                   0.0     Pacific            Av
# 3  0156  011           1230                   0.0     Pacific            Av
# ...
